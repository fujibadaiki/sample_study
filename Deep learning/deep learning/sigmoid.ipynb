# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#figure内の領域設定
n_clos = 1
n_rows = 1

# %%
plt.figure(figsize=(6,8))

# %%
x = np.arange(-5,5,0.1)

# %%
#
#sigmoid
#
y = 1./(1. + np.exp(-x))
plt.subplot(n_rows,n_clos,1)
plt.title('Sigmoid')
plt.ylim(-1,1)
plt.plot(x,y)
